# %% [markdown]
# # 4&5の課題

# %% [markdown]
# 学生番号：

# %% [markdown]
# 氏　　名：

# %% [markdown]
# #### ■1. 引数の数が偶数か奇数かを判定する関数を作成する。
#
# □1-1. 引数に整数をいれて，偶数と奇数を入力して判定する`even_or_odd(数値)`を作れ。ただし数値に実数が入ったときには，そのを数値の整数部分だけで偶数と奇数を判定すること。なお、出力は`print`関数を用いて，引数の`数値`が偶数のときは`Even`，奇数のときは`Odd`と表示すること。

# %%
def even_or_odd(val):
    ival = int(val)
    if ival%2 == 0:
        print('Even')
    else:
        print('Odd')

# %% [markdown]
# □1-2. 引数の数値が23088のとき，その数が偶数か奇数かを判定せよ：

# %%
even_or_odd(23088)
# Out:
# Even

# %% [markdown]
# □1-3. 引数の数値が18905のとき，その数が偶数か奇数かを判定せよ：

# %%
even_or_odd(18905)
# Out:
# Odd

# %% [markdown]
# □1-4. 引数の数値が76.3のとき，その数の整数部分が偶数か奇数かを判定せよ：

# %%
even_or_odd(67.3)
# Out:
# Odd

# %% [markdown]
# #### ■2. 引数の数がnの倍数かどうかを判定する。ただし，論理値を返す。
#
# □2-1. 引数で指定した数（の整数部分）が$n$の倍数かを判定する関数`n_maltiple(数値, n)`を作れ。ただし、今回は引数の`数値`（の整数部分が）`n`の倍数の場合は`True`を**返し**，そうでない場合は`False`を**返す**。

# %%
def is_maltiple(val, n):
    ival = int(val)
    if ival%n == 0:
        return True
    else:
        return False

# %% [markdown]
# □2-2a. 引数の数値が21858909のとき，その数が7の倍数どうかを判定せよ：

# %%
is_maltiple(21858909, 7)
# Out:
# False

# %% [markdown]
# □2-2b. 21858909は7の倍数か？ 下のセルに記述せよ：

# %% [markdown]
# （ここをダブルクリックして入力）

# %% [markdown]
# □2-3a. 引数の数値が111222333のとき，その数が9の倍数かを判定せよ：

# %%
is_maltiple(111222333, 9)
# Out:
# True

# %% [markdown]
# □2-3b. 111222333は9の倍数か？ 下のセルに記述せよ：

# %% [markdown]
# （ここをダブルクリックして入力）

# %% [markdown]
# □2-4a. 引数の数値–875394.38のとき，その数の整数部分が6の倍数かを判定せよ。

# %%
is_maltiple(-875394.38, 6)
# Out:
# True

# %% [markdown]
# □2-4b. –875394.38の整数部分は6の倍数か？ 下のセルに記述せよ：

# %% [markdown]
# （ここをダブルクリックして入力）

# %% [markdown]
# #### ■3. エラーの対応についての問題に答えよ。
# 下の幾つかのコードを実行するとエラーが出る（問題番号末尾aのセル）。エラーを起こした原因を調べて（問題番号末尾bのセルに）述べ，その下のセル（問題番号末尾cのセル）に元の（問題番号末尾aのセルの）コードをコピー＆ペーストしてエラー発生コード修正し実行せよ。
#
# □3-1a. nのn乗を求めるコード（エラーが出る）：

# %%
def n_no_n_joh(n);
    return x**x

n_no_n_joh(45)
# Out:
#   File "<ipython-input-21-be97330cede7>", line 1
#     def n_no_n_joh(n);
#                      ^
# SyntaxError: expected ':'

# %% [markdown]
# □3-1b. 3-1aの何行目の何がエラーであるか？

# %% [markdown]
# （ここをダブルクリックして入力）

# %% [markdown]
# □3-1c. 3-1aのコードを修正して実行せよ：

# %%
def n_no_n_joh(n):
    return n**n

n_no_n_joh(45)
# Out:
# 248063644451341145494649182395412689744530581492654164321720600128173828125

# %% [markdown]
# □3-2a. 角度（60分法）を与えたときのsin, cos, tan の値を表示するコード（エラーが出る）：

# %%
def triangle_ratio(theta):
    print(f'sin({theta}degrees)={math.sin(math.radians(theta))}')
    print(f'cos({theta}degrees)={math.cos(math.radians(theta))}')
    print(f'tan({theta}degrees)={math.tan(math.radians(theta))}')


triangle_ratio(60)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-26-1f30be8f4e8c> in <cell line: 7>()
#       5
#       6
# ----> 7 triangle_ratio(60)
#
# <ipython-input-26-1f30be8f4e8c> in triangle_ratio(theta)
#       1 def triangle_ratio(theta):
# ----> 2     print(f'sin({theta}degrees)={math.sin(math.readians(theta))}')
#       3     print(f'sin({theta}degrees)={math.sin(math.readians(theta))}')
#       4     print(f'sin({theta}degrees)={math.sin(math.readians(theta))}')
#       5
#
# NameError: name 'math' is not defined

# %% [markdown]
# □3-2b. 3-2aの何がエラーであるか？

# %% [markdown]
# （ダブルクリックして入力）

# %% [markdown]
# □3-2c. 3-2aのコードを修正して実行せよ：

# %%
import math

def triangle_ratio(theta):
    print(f'sin({theta}degrees)={math.sin(math.radians(theta))}')
    print(f'cos({theta}degrees)={math.cos(math.radians(theta))}')
    print(f'tan({theta}degrees)={math.tan(math.radians(theta))}')


triangle_ratio(60)
# Out:
# sin(60degrees)=0.8660254037844386
# cos(60degrees)=0.5000000000000001
# tan(60degrees)=1.7320508075688767

# %% [markdown]
# □3-3a. 次のプログラムは`n`($=n$)を与えたとき，$1^2+2^2+3^2+...+(n-1)^2+n^2$を計算し，結果を表示するコードである（エラーがでる）：

# %%
def ni_johwa(n):
    s = 0
    for k in range(n):
        s += k**2
    print(f'1^2 + 2^2 + 3^2 + ... + {n}^2 = {s}")

ni_johwa(10)
# Out:
#   File "<ipython-input-4-8bf988e8564b>", line 5
#     print(f'1^2 + 2^2 + 3^2 + ... + {n}^2 = {s}")
#           ^
# SyntaxError: unterminated string literal (detected at line 5)

# %% [markdown]
# □3-3b. 3-1aの何行目の何がエラーであるか？

# %% [markdown]
# （ダブルクリックして入力）

# %% [markdown]
# 3-3c. 3-3aのコードを修正して実行せよ：

# %%
def ni_johwa(n):
    s = 0
    for k in range(n):
        s += k**2
    print(f'1^2 + 2^2 + 3^2 + ... + {n}^2 = {s}')

ni_johwa(10)
# Out:
# 1^2 + 2^2 + 3^2 + ... + 10^2 = 285
